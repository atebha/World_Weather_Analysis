# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# !pip install gmaps

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID               City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0            Rikitea      PF -23.1203 -134.9692     78.96        79
# 1        1    Arraial Do Cabo      BR -22.9661  -42.0278     71.46        64
# 2        2          Joshimath      IN  30.5667   79.5667     69.80        50
# 3        3  Monforte De Lemos      ES  42.5216   -7.5142     35.01        93
# 4        4            Mataura      NZ -46.1927  168.8643     55.99        74
#
#    Cloudiness  Wind Speed Current Description
# 0          79       20.36       broken clouds
# 1          35        5.12    scattered clouds
# 2          26        4.56    scattered clouds
# 3          58        3.00       broken clouds
# 4          65        3.00       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the coldest temperature you would like for your trip? "))
max_temp = float(input("What is the warmest temperature you would like for your trip? "))
# Out:
# What is the coldest temperature you would like for your trip? 65
# What is the warmest temperature you would like for your trip? 99

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
dest_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
dest_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0          Rikitea      PF -23.1203 -134.9692     78.96        79
# 1         1  Arraial Do Cabo      BR -22.9661  -42.0278     71.46        64
# 2         2        Joshimath      IN  30.5667   79.5667     69.80        50
# 6         6        Busselton      AU -33.6500  115.3333     66.00        72
# 8         8           Shingu      JP  33.7333  135.9833     66.20        88
# 11       11      New Norfolk      AU -42.7826  147.0587     68.00        52
# 14       14         Luderitz     NaN -26.6481   15.1594     65.25        38
# 18       18             Daru      PG  -9.0763  143.2092     81.27        80
# 21       21           Viedma      AR -40.8135  -62.9967     65.55        49
# 22       22        Kavaratti      IN  10.5669   72.6420     85.17        71
#
#     Cloudiness  Wind Speed Current Description
# 0           79       20.36       broken clouds
# ...

# %%
# 4a. Determine if there are any empty rows.
dest_df.count()
# Out:
# City_ID                337
# City                   337
# Country                336
# Lat                    337
# Lng                    337
# Max Temp               337
# Humidity               337
# Cloudiness             337
# Wind Speed             337
# Current Description    337
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
nan_value = float("NaN")
dest_df.replace("", nan_value, inplace = True)
dest_df.dropna(subset = ["Country"], inplace = True)
dest_df
# Out:
# C:\Users\tebha.ahsan\Anaconda3\lib\site-packages\pandas\core\frame.py:4379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# <ipython-input-10-eda4430892d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dest_df.dropna(subset = ["Country"], inplace = True)
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0          Rikitea      PF -23.1203 -134.9692     78.96        79
# 1          1  Arraial Do Cabo      BR -22.9661  -42.0278     71.46        64
# 2          2        Joshimath      IN  30.5667   79.5667     69.80        50
# ...

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = dest_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 0           Rikitea      PF     78.96       broken clouds -23.1203 -134.9692
# 1   Arraial Do Cabo      BR     71.46    scattered clouds -22.9661  -42.0278
# 2         Joshimath      IN     69.80    scattered clouds  30.5667   79.5667
# 6         Busselton      AU     66.00     overcast clouds -33.6500  115.3333
# 8            Shingu      JP     66.20                mist  33.7333  135.9833
# 11      New Norfolk      AU     68.00     overcast clouds -42.7826  147.0587
# 18             Daru      PG     81.27     overcast clouds  -9.0763  143.2092
# 21           Viedma      AR     65.55     overcast clouds -40.8135  -62.9967
# 22        Kavaratti      IN     85.17    scattered clouds  10.5669   72.6420
# 23             Hilo      US     80.60     overcast clouds  19.7297 -155.0900
#
#    Hotel Name
# 0
# 1
# 2
# 6
# 8
# 11
# 18
# 21
# 22
# 23

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotel = requests.get(base_url, params = params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index,"Hotel Name"] = hotel["results"][0]["name"]
    except (IndexError):
        print("hotel not found... skipping")
hotel_df
# Out:
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
# hotel not found... skipping
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 0            Rikitea      PF     78.96       broken clouds -23.1203 -134.9692
# 1    Arraial Do Cabo      BR     71.46    scattered clouds -22.9661  -42.0278
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
nan_value = float("NaN")
hotel_df.replace("", nan_value, inplace = True)
hotel_df.dropna(subset = ["Hotel Name"], inplace = True)

hotel_df
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 0            Rikitea      PF     78.96       broken clouds -23.1203 -134.9692
# 1    Arraial Do Cabo      BR     71.46    scattered clouds -22.9661  -42.0278
# 2          Joshimath      IN     69.80    scattered clouds  30.5667   79.5667
# 6          Busselton      AU     66.00     overcast clouds -33.6500  115.3333
# 8             Shingu      JP     66.20                mist  33.7333  135.9833
# ..               ...     ...       ...                 ...      ...       ...
# 677       Nouadhibou      MR     66.20           clear sky  20.9310  -17.0347
# 681         Cam Ranh      VN     87.80          few clouds  11.9214  109.1591
# 682          Chitral      PK     67.66           clear sky  35.8462   71.7858
# 683          Cotonou      BJ     82.40          few clouds   6.3654    2.4183
# 685       Port Keats      AU     91.31           clear sky -14.2500  129.5500
#
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_Vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level = 1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
